# %% [markdown]
# # Peças Tracionadas
# (Tração paralela às fibras)

# %% [markdown]
#  - Comportamento elasto-frágil até à ruptura, sem a ocorrência de valores significativos de deformações antes do rompimento;
#  - Tração paralela às fibras ocorre principalmente nas treliças e nos tirantes de madeira.
#  - Quando as tensões de **tração perpendicular às fibras** puderem atingir valores significativos, devem ser utilizados dispositivos que impeçam a ruptura decorrente dessas tensões.
#
# ### Item 6.3.2 da ABNT NBR 7190(Parte 1)/2022:
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Exercício
#
# Qual o máximo valor de F pra o tirante($16x8cm$)  representado abaixo:
#
# ![image.png](attachment:image.png)
#
# - Pinho do paraná, 12% de umidade

# %% [markdown]
# - SOLUÇÃO:
#
# $\sigma N_{td} = \frac{N_{t,d}}{A}\leq f_{t,0d} \therefore N_{t,d} = f_{t,0d} \times A $
#
# Área líquida da seção transversal($A$):

# %%
A = (16 - 4) * 8 *1e-4 
A
# Out:
# 0.009600000000000001

# %% [markdown]
# K_mod = 0.60 * 1

# %%
gama_w = 1.4

# %%
fc_0m = 43.1 #[MPa] https://www.prefeitura.sp.gov.br/cidade/secretarias/upload/arquivos/secretarias/meio_ambiente/fauna_flora/manual_madeira/manual_da_madeira_pinho_parana.pdf
fc_0d = 0.7 * fc_0m

# %%
ft_0d = fc_0d * K_mod / gama_w
ft_0d
# Out:
# 12.929999999999998

# %%
Ntd =  ft_0d * A * 1e3
print("Ntd = ", Ntd, "kN")
# Out:
# Ntd =  124.12799999999999 kN
